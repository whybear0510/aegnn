# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.animation import FuncAnimation
from mpl_toolkits.mplot3d import Axes3D


path = "/space/yyang22/datasets/data/storage/ncars/validation/sequence_12964/"
events = np.loadtxt(path+'events.txt')
is_car = np.loadtxt(path+'is_car.txt')
print(events)
print(is_car)
# Out:
# [[4.4000e+01 1.5000e+01 0.0000e+00 0.0000e+00]
#  [3.8000e+01 1.0000e+00 2.4000e-05 0.0000e+00]
#  [2.9000e+01 2.0000e+00 1.1910e-03 1.0000e+00]
#  ...
#  [9.0000e+00 2.0000e+01 9.9747e-02 0.0000e+00]
#  [1.0000e+00 2.2000e+01 9.9750e-02 0.0000e+00]
#  [3.8000e+01 3.2000e+01 9.9860e-02 0.0000e+00]]
# 1.0

# %%
colors = []
for i in range(events.shape[0]):
    color = 'b' if events[i,3] == 1 else 'r'
    colors.append(color)
# print(colors)

# %%
fig = plt.figure()
ax = Axes3D(fig)

ax.set_xlim(0,np.max(events[:,0]))
ax.set_zlim(0,np.max(events[:,1]))
ax.set_ylim(-0.1,0)

# def update(n):
#     x = events[n,0]
#     y = events[n,1]
#     t = -events[n,2]
#     c = colors[n]
#     ax.scatter(x, t, y, c=c, s=0.5)
# ani = FuncAnimation(fig, update, events.shape[0], interval=100)
# ani.save('scatter.gif', writer='pillow')

ax.scatter(events[:,0], -events[:,2], events[:,1], c=colors, s=0.5)

plt.show()
# Out:
# /tmp/ipykernel_2880765/3002631166.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
